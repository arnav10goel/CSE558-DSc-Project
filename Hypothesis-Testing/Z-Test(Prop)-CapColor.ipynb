# %%
import pandas as pd
import numpy as np
import itertools
import seaborn as sns
from tabulate import tabulate
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from statsmodels.stats.proportion import proportions_ztest
from scipy.stats import chi2_contingency
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
df_no_encoded = pd.read_csv("Data_Preproc_NoEncoding.csv")

# %%
df_encoded = pd.read_csv("Data_Preproc_Encoded.csv")

# %%
df_class = pd.read_csv("Labels.csv")

# %%
df_class.replace('p', 1, inplace=True)
df_class.replace('e', 0, inplace=True)

# %%
contingency_table = pd.crosstab(df_no_encoded['cap-color'], df_class['class'])

# %%
contingency_table
# Out:
# class          0      1
# cap-color
# b            974    256
# e            880   3155
# g           2297   2123
# k            501    778
# l            452    376
# n          12407  11811
# o           1071   2585
# p            449   1254
# r            198   1584
# u            611   1098
# w           3750   3916
# y           3591   4952

# %% [markdown]
# sample 10% of each cap-color group

# %%
sampled_table = contingency_table.apply(lambda row: (row * 0.10).round())

# %%
combinations = list(itertools.combinations(sampled_table.index, 2))

print("\nPairwise Two-Proportion Z-tests on Sample:")

alpha = 0.05
for combo in combinations:
    count1 = sampled_table.loc[combo[0], 1]
    count2 = sampled_table.loc[combo[1], 1]
    nobs1 = sum(sampled_table.loc[combo[0]])
    nobs2 = sum(sampled_table.loc[combo[1]])

    stat, pval = proportions_ztest([count1, count2], [nobs1, nobs2])

    print(f"\nComparing {combo[0]} vs {combo[1]}:")
    print(f"Z-statistic: {stat}")
    print(f"P-value: {pval}")

    if pval < alpha:
        print(f"The proportions of successes between {combo[0]} and {combo[1]} are significantly different.")
    else:
        print(f"No significant difference in proportions between {combo[0]} and {combo[1]}.")
# Out:
# Pairwise Two-Proportion Z-tests on Sample:
#
# Comparing b vs e:
# Z-statistic: -11.612631068906298
# P-value: 3.5550537785408604e-31
# The proportions of successes between b and e are significantly different.
#
# Comparing b vs g:
# Z-statistic: -5.329357255385819
# P-value: 9.856095029033209e-08
# The proportions of successes between b and g are significantly different.
#
# Comparing b vs k:
# Z-statistic: -6.398738672189651
# P-value: 1.566657086067309e-10
# The proportions of successes between b and k are significantly different.
#
# Comparing b vs l:
# Z-statistic: -3.749026289566177
# P-value: 0.00017752247763547276
# The proportions of successes between b and l are significantly different.
#
# Comparing b vs n:
# Z-statistic: -5.985148307250141
# P-value: 2.161927796213129e-09
# The proportions of successes between b and n are significantly different.
#
# Comparing b vs o:
# Z-statistic: -9.634952007100905
# P-value: 5.691859136667364e-22
# The proportions of successes between b and o are significantly different.
#
# Comparing b vs p:
# Z-statistic: -8.855978016887702
# P-value: 8.295322937457098e-19
# The proportions of successes between b and p are significantly different.
#
# Comparing b vs r:
# Z-statistic: -11.83195729760058
# P-value: 2.668458432745683e-32
# The proportions of successes between b and r are significantly different.
#
# Comparing b vs u:
# Z-statistic: -7.326594948243986
# P-value: 2.3607395733506067e-13
# The proportions of successes between b and u are significantly different.
#
# Comparing b vs w:
# Z-statistic: -6.182624621609527
# P-value: 6.304450526768978e-10
# The proportions of successes between b and w are significantly different.
#
# Comparing b vs y:
# Z-statistic: -7.653537262261577
# P-value: 1.9552494749289006e-14
# The proportions of successes between b and y are significantly different.
#
# Comparing e vs g:
# Z-statistic: 9.074852601818455
# P-value: 1.1383146792129184e-19
# The proportions of successes between e and g are significantly different.
#
# Comparing e vs k:
# Z-statistic: 3.887009971651924
# P-value: 0.00010148658664589627
# The proportions of successes between e and k are significantly different.
#
# Comparing e vs l:
# Z-statistic: 6.040550219473238
# P-value: 1.5358957032278638e-09
# The proportions of successes between e and l are significantly different.
#
# Comparing e vs n:
# Z-statistic: 10.981738661644295
# P-value: 4.67831845193592e-28
# The proportions of successes between e and n are significantly different.
#
# Comparing e vs o:
# Z-statistic: 2.3976659419694504
# P-value: 0.016499905371584737
# The proportions of successes between e and o are significantly different.
#
# Comparing e vs p:
# Z-statistic: 1.2154904736584138
# P-value: 0.22417907995273634
# No significant difference in proportions between e and p.
#
# Comparing e vs r:
# Z-statistic: -3.0154913315216856
# P-value: 0.0025656327251225124
# The proportions of successes between e and r are significantly different.
#
# Comparing e vs u:
# Z-statistic: 3.474861426720626
# P-value: 0.0005111173094485251
# The proportions of successes between e and u are significantly different.
#
# Comparing e vs w:
# Z-statistic: 9.019509595115176
# P-value: 1.8893315939720125e-19
# The proportions of successes between e and w are significantly different.
#
# Comparing e vs y:
# Z-statistic: 7.008648328511858
# P-value: 2.4063143079645935e-12
# The proportions of successes between e and y are significantly different.
#
# Comparing g vs k:
# Z-statistic: -2.585469111462093
# P-value: 0.00972465857955577
# The proportions of successes between g and k are significantly different.
#
# Comparing g vs l:
# Z-statistic: 0.36499179914869795
# P-value: 0.7151175279201911
# No significant difference in proportions between g and l.
#
# Comparing g vs n:
# Z-statistic: -0.3085052496993545
# P-value: 0.7576979062441549
# No significant difference in proportions between g and n.
#
# Comparing g vs o:
# Z-statistic: -6.514189570684245
# P-value: 7.308315281131297e-11
# The proportions of successes between g and o are significantly different.
#
# Comparing g vs p:
# Z-statistic: -5.6949010590399345
# P-value: 1.2344348546497213e-08
# The proportions of successes between g and p are significantly different.
#
# Comparing g vs r:
# Z-statistic: -9.369337320366698
# P-value: 7.298934047388449e-21
# The proportions of successes between g and r are significantly different.
#
# Comparing g vs u:
# Z-statistic: -3.6386986833234407
# P-value: 0.00027401918131965
# The proportions of successes between g and u are significantly different.
#
# Comparing g vs w:
# Z-statistic: -1.053089740662906
# P-value: 0.2922998644188606
# No significant difference in proportions between g and w.
#
# Comparing g vs y:
# Z-statistic: -3.4270464174716597
# P-value: 0.0006101847569931932
# The proportions of successes between g and y are significantly different.
#
# Comparing k vs l:
# Z-statistic: 2.161385708044913
# P-value: 0.03066555717882803
# The proportions of successes between k and l are significantly different.
#
# Comparing k vs n:
# Z-statistic: 2.685319689209432
# P-value: 0.00724604606959305
# The proportions of successes between k and n are significantly different.
#
# Comparing k vs o:
# Z-statistic: -2.0367869511139816
# P-value: 0.04167139651236988
# The proportions of successes between k and o are significantly different.
#
# Comparing k vs p:
# Z-statistic: -2.308976047611963
# P-value: 0.020944910424791803
# The proportions of successes between k and p are significantly different.
#
# Comparing k vs r:
# Z-statistic: -5.716496785980174
# P-value: 1.0874252592846448e-08
# The proportions of successes between k and r are significantly different.
#
# Comparing k vs u:
# Z-statistic: -0.6003382921400048
# P-value: 0.5482808038557181
# No significant difference in proportions between k and u.
#
# Comparing k vs w:
# Z-statistic: 2.061544767706619
# P-value: 0.0392510971217794
# The proportions of successes between k and w are significantly different.
#
# Comparing k vs y:
# Z-statistic: 0.6366978680589703
# P-value: 0.5243216625292573
# No significant difference in proportions between k and y.
#
# Comparing l vs n:
# Z-statistic: -0.533782916859675
# P-value: 0.5934917342606776
# No significant difference in proportions between l and n.
#
# Comparing l vs o:
# Z-statistic: -4.325014410328153
# P-value: 1.5252189164546632e-05
# The proportions of successes between l and o are significantly different.
#
# Comparing l vs p:
# Z-statistic: -4.328261216759555
# P-value: 1.5029115627310137e-05
# The proportions of successes between l and p are significantly different.
#
# Comparing l vs r:
# Z-statistic: -7.477565356766446
# P-value: 7.571211741832673e-14
# The proportions of successes between l and r are significantly different.
#
# Comparing l vs u:
# Z-statistic: -2.8111359655741386
# P-value: 0.0049366919430427645
# The proportions of successes between l and u are significantly different.
#
# Comparing l vs w:
# Z-statistic: -0.9217508778936665
# P-value: 0.35665853539553927
# No significant difference in proportions between l and w.
#
# Comparing l vs y:
# Z-statistic: -2.1389925293381893
# P-value: 0.032436273412832596
# The proportions of successes between l and y are significantly different.
#
# Comparing n vs o:
# Z-statistic: -7.81336408703844
# P-value: 5.5681451892537175e-15
# The proportions of successes between n and o are significantly different.
#
# Comparing n vs p:
# Z-statistic: -6.243511318686249
# P-value: 4.2785533296020043e-10
# The proportions of successes between n and p are significantly different.
#
# Comparing n vs r:
# Z-statistic: -10.306830095314254
# P-value: 6.563042474462744e-25
# The proportions of successes between n and r are significantly different.
#
# Comparing n vs u:
# Z-statistic: -3.9345806728508643
# P-value: 8.334207278729162e-05
# The proportions of successes between n and u are significantly different.
#
# Comparing n vs w:
# Z-statistic: -1.1329586884910674
# P-value: 0.25723160220647623
# No significant difference in proportions between n and w.
#
# Comparing n vs y:
# Z-statistic: -4.62523969895528
# P-value: 3.7416543860530666e-06
# The proportions of successes between n and y are significantly different.
#
# Comparing o vs p:
# Z-statistic: -0.6792498119573017
# P-value: 0.49697959046822815
# No significant difference in proportions between o and p.
#
# Comparing o vs r:
# Z-statistic: -4.671807635417542
# P-value: 2.9856051055088576e-06
# The proportions of successes between o and r are significantly different.
#
# Comparing o vs u:
# Z-statistic: 1.478873479007133
# P-value: 0.13917413270181447
# No significant difference in proportions between o and u.
#
# Comparing o vs w:
# Z-statistic: 6.226256500363462
# P-value: 4.777117400739953e-10
# The proportions of successes between o and w are significantly different.
#
# Comparing o vs y:
# Z-statistic: 4.186546276476596
# P-value: 2.8323120819952777e-05
# The proportions of successes between o and y are significantly different.
#
# Comparing p vs r:
# Z-statistic: -3.645072656424192
# P-value: 0.000267316269275926
# The proportions of successes between p and r are significantly different.
#
# Comparing p vs u:
# Z-statistic: 1.8356572597344376
# P-value: 0.06640836285281956
# No significant difference in proportions between p and u.
#
# Comparing p vs w:
# Z-statistic: 5.318397997029053
# P-value: 1.0468488098519388e-07
# The proportions of successes between p and w are significantly different.
#
# Comparing p vs y:
# Z-statistic: 3.7924380401581184
# P-value: 0.00014917547773606542
# The proportions of successes between p and y are significantly different.
#
# Comparing r vs u:
# Z-statistic: 5.405687362452914
# P-value: 6.45603228461585e-08
# The proportions of successes between r and u are significantly different.
#
# Comparing r vs w:
# Z-statistic: 9.176475985925073
# P-value: 4.4542985272320046e-20
# The proportions of successes between r and w are significantly different.
#
# Comparing r vs y:
# Z-statistic: 7.754872773232983
# P-value: 8.843208850763145e-15
# The proportions of successes between r and y are significantly different.
#
# Comparing u vs w:
# Z-statistic: 3.134076387613199
# P-value: 0.001723959710802246
# The proportions of successes between u and w are significantly different.
#
# Comparing u vs y:
# Z-statistic: 1.5448346564472155
# P-value: 0.12238626216175068
# No significant difference in proportions between u and y.
#
# Comparing w vs y:
# Z-statistic: -2.768040071036662
# P-value: 0.005639452136999334
# The proportions of successes between w and y are significantly different.

# %% [markdown]
# 1. **Significant Differences in Proportions**:
#    - **b vs. e**: There's a significant difference between the proportions of edible and poisonous mushrooms with caps colored 'b' and 'e'. The negative Z-score indicates that 'b' has a lower proportion of edible mushrooms than 'e'.
#    - **g vs. y**: Similarly, there's a significant difference between the proportions of edible and poisonous mushrooms with caps colored 'g' and 'y'. With the positive Z-score, 'g' has a higher proportion of edible mushrooms than 'y'.
#    - **b vs. y**: The positive Z-score suggests that the proportion of edible mushrooms with cap color 'b' is higher than those with cap color 'y'.
#
# 2. **Non-significant Differences in Proportions**:
#    - **e vs. g**: There's no significant difference between the proportions of edible and poisonous mushrooms with cap colors 'e' and 'g'.
#    - **e vs. y**: Similarly, there's no significant difference between the proportions of edible and poisonous mushrooms with cap colors 'e' and 'y'.
#    - **g vs. b**: The proportions of edible and poisonous mushrooms with cap colors 'g' and 'b' are not significantly different.
#
# **Implications**:
# If the goal is to understand which cap colors are more commonly associated with edible mushrooms (and which with poisonous ones), this analysis suggests:
# - Mushrooms with cap color 'b' might have a higher likelihood of being edible compared to those with cap color 'y'.
# - Mushrooms with cap color 'g' might also have a higher likelihood of being edible compared to those with cap color 'y'.
# - However, when comparing cap colors 'b', 'e', and 'g' among themselves, the differences in proportions of edibility are less clear or non-significant.

# %%
chi2, p, _, _ = chi2_contingency(contingency_table)

print(f"Chi-squared Value = {chi2}")
print(f"P-value = {p}")

alpha = 0.05
if p < alpha:
    print("We reject the null hypothesis. There's a significant association between cap-color and class.")
else:
    print("We fail to reject the null hypothesis. No significant association between cap-color and class.")
# Out:
# Chi-squared Value = 3541.079818275377
# P-value = 0.0
# We reject the null hypothesis. There's a significant association between cap-color and class.

# %% [markdown]
# Given that Chi-squared Value is quite high and the P-value is essentially 0, it's very clear that the cap color and edibility are not independent.
#
# Thus, the cap color of a mushroom could be considered as one of the predictors or indicators of its edibility, at least based on this dataset. However, caution should always be taken when using such results in real-world applications, especially when health and safety are concerned. Always remember that while there's a significant association between the two variables in this dataset, it does not guarantee that this association will hold true in every scenario or region. Other factors could also come into play, and proper identification by experts is essential.
